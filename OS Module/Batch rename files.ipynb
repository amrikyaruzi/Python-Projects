# %% [markdown]
# Batch renaming downloaded files

# %%
import os

# %%
os.chdir("E:/Downloads/Videos")

# %%
files = os.listdir()
print(files)
# Out:
# ['1. From OnePlus', '11 Tips And Tricks To Write Better Python Code.mp4', "12 Office Desk Setup Accessories You've Never Heard Of!.mp4", '15 Types of Bar Chart in Tableau - Part 2 _ Tableau Advance Bar Charts.mp4', '15 Types of Bar Charts in Tableau   Part 1.mp4', '18 Commands That Will Change The Way You Use Linux Forever.mp4', '5 Excel INTERVIEW Questions You NEED to Get RIGHT.mp4', 'A Day In The Life Of An Amazon Software Engineer (Seattle Edition).mp4', 'A Simple Introduction to Data Analysis in Microsoft Excel.mp4', 'A Weapon that Cannot be Re-loaded Quickly #shorts.mp4', 'Advance Python Programming Full Course  Python Full Course  Learn Python In One Video Simplilearn.mp4', 'Advance Python Tutorial Full Course  4 Hours  2022.mp4', 'Advanced Pivot Tables Tutorial in Excel - 2.5 Hour Pivot Table Excel Course.mp4', 'Advanced Python', 'Advanced R Book Club - Chapter 6 Functions (2020-05-07) (advr01).mp4', 'Advanced R Book Club - Chapter 8  Conditions (2020-05-21) (advr01).mp4', 'Advanced R Book Club Chapter 3 Vectors (2020-04-16) (advr01).mp4', 'Advanced R Book Club Chapter 5 Control Flow (2020-04-30) (advr01).mp4', 'Always Do THIS with a New Laptop.mp4', 'Angelina Frimpong', 'AP Statistics  RStudio Random Sampling & For Loops.mp4', 'Apple makes my brain hurt….mp4', 'APUs are the FUTURE - featuring the Minisforum TH50.mp4', 'Brad Lindblad  Professional Financial Reports with {rmarkdown}  RStudio.mp4', "Breaking News! We FINALLY get the Excel functions we've been Wanting!.mp4", 'Building Predictive Web Applications with R Shiny  1-Hour Webinars.mp4', 'C++ FULL COURSE For Beginners (Learn C++ in 10 hours).mp4', 'C++ Programming Course - Beginner to Advanced.mp4', 'Carson Sievert  Custom Theming with {bslib} in Shiny and R Markdown using bs_theme()  RStudio.mp4', 'Carson Sievert  Developing Shiny Custom Themes in Real Time Using {bslib} RStudio.mp4', 'CC++ Tutorial for Beginners - Install GNU (GCCG++) Compiler Tools on Windows 10 - MinGW.mp4', 'COMPLETELY Paralyzed Man Walks After Spine Implant.mp4', 'Cooking', 'Creating an ATS-Friendly Resume Using Microsoft Word.mp4', 'Creating an Interactive Dashboard in Excel Using Pivot Tables, Pivot Charts and Slicers.mp4', 'Creating Dashboards for Mobile in Tableau.mp4', 'CSS Tutorial - Zero to Hero (Complete Course).mp4', 'Data & Programming', 'DATA Analysis using SQL.mp4', 'Data Analysis with Python Course - Numpy, Pandas, Data Visualization.mp4', 'Data Analyst Portfolio Project  SQL Data Exploration  Project 14.mp4', 'Data Analyst Projects _ Cleaning and Exploring Data with Python _ Part 3.mp4', 'Data Analyst Projects _ Cleaning and Exploring Data with SQL _ Part 1.mp4', 'Data Analyst Projects _ Visualizing Data with Tableau _ Part 2.mp4', 'Data Analytics Using Python And SQL 2022 _ Data Analytics Full Course For Beginners _ Simplilearn.mp4', 'DataEditR Tutorial - Interactively Edit Datasets Using R.mp4', 'DAX In Excel Explained  Excel DAX Formulas And DAX Functions  Excel Tutorial  Simplilearn.mp4', 'Day in the Life of a Software Engineer - First Person View - Working at the Kahoot Office.mp4', 'Decision Trees in R   Rpart Library.mp4', 'Deep Maths - machine learning and mathematics.mp4', 'Deploy you Machine Learning model with Python.mp4', 'Depressed Parents Take Revenge On Psychopath Who K1lled Their Son.mp4', 'Did Russia Want to Take Kiev That Was Never the Plan Says Russia.mp4', 'Do Sanctions Work_.mp4', 'Documentary', 'DON’T WASTE YOUR MONEY!! iPad Pro vs Galaxy Tab S8 Ultra.mp4', 'EASILY UNLOCK Protected Excel Sheets WITHOUT Password.mp4', 'English', 'Excel 2019 Pivot Tables Tutorial.mp4', 'Excel Crash Course - Data Cleaning in Excel - Microsoft Excel Tutorial.mp4', 'Excel Interview Questions For Data Analyst.mp4', 'Excel Tips & Tricks_ Designing Better Spreadsheets - 1-hour Excel Tutorial.mp4', 'Excel Tutorials - Top Ten Excel Functions you HAVE to know - Excel 2019 (IF, VLOOKUP, SUM, PMT).mp4', 'Fedora is the new Ubuntu - Fedora Long Term Review.mp4', 'Firefox DYING is TERRIB ...

# %%
for file in files:
    filename, ext = os.path.splitext(file)
    
    filename = filename.title()
    filename = filename.replace("_", " ")
    filename = filename.replace(".", " ")

    newname = f'{filename}{ext}'
    print(newname)
    
    #os.rename(file, newname)
# Out:
# 1. From OnePlus
# 11 Tips And Tricks To Write Better Python Code.mp4
# 12 Office Desk Setup Accessories You'Ve Never Heard Of!.mp4
# 15 Types Of Bar Chart In Tableau - Part 2   Tableau Advance Bar Charts.mp4
# 15 Types Of Bar Charts In Tableau   Part 1.mp4
# 18 Commands That Will Change The Way You Use Linux Forever.mp4
# 5 Excel Interview Questions You Need To Get Right.mp4
# A Day In The Life Of An Amazon Software Engineer (Seattle Edition).mp4
# A Simple Introduction To Data Analysis In Microsoft Excel.mp4
# A Weapon That Cannot Be Re-Loaded Quickly #Shorts.mp4
# Advance Python Programming Full Course  Python Full Course  Learn Python In One Video Simplilearn.mp4
# Advance Python Tutorial Full Course  4 Hours  2022.mp4
# Advanced Pivot Tables Tutorial In Excel - 2 5 Hour Pivot Table Excel Course.mp4
# Advanced Python
# Advanced R Book Club - Chapter 6 Functions (2020-05-07) (Advr01).mp4
# Advanced R Book Club - Chapter 8  Conditions (2020-05-21) (Advr01).mp4
# Advanced R Book Club Chapter 3 Vectors (2020-04-16) (Advr01).mp4
# Advanced R Book Club Chapter 5 Control Flow (2020-04-30) (Advr01).mp4
# Always Do This With A New Laptop.mp4
# Angelina Frimpong
# Ap Statistics  Rstudio Random Sampling & For Loops.mp4
# Apple Makes My Brain Hurt….mp4
# Apus Are The Future - Featuring The Minisforum Th50.mp4
# Brad Lindblad  Professional Financial Reports With {Rmarkdown}  Rstudio.mp4
# Breaking News! We Finally Get The Excel Functions We'Ve Been Wanting!.mp4
# Building Predictive Web Applications With R Shiny  1-Hour Webinars.mp4
# C++ Full Course For Beginners (Learn C++ In 10 Hours).mp4
# C++ Programming Course - Beginner To Advanced.mp4
# Carson Sievert  Custom Theming With {Bslib} In Shiny And R Markdown Using Bs Theme()  Rstudio.mp4
# Carson Sievert  Developing Shiny Custom Themes In Real Time Using {Bslib} Rstudio.mp4
# Cc++ Tutorial For Beginners - Install Gnu (Gccg++) Compiler Tools On Windows 10 - Mingw.mp4
# Completely Paralyzed Man Walks After Spine Implant.mp4
# Cooking
# Creating An Ats-Friendly Resume Using Microsoft Word.mp4
# Creating An Interactive Dashboard In Excel Using Pivot Tables, Pivot Charts And Slicers.mp4
# Creating Dashboards For Mobile In Tableau.mp4
# Css Tutorial - Zero To Hero (Complete Course).mp4
# Data & Programming
# Data Analysis Using Sql.mp4
# Data Analysis With Python Course - Numpy, Pandas, Data Visualization.mp4
# Data Analyst Portfolio Project  Sql Data Exploration  Project 14.mp4
# Data Analyst Projects   Cleaning And Exploring Data With Python   Part 3.mp4
# Data Analyst Projects   Cleaning And Exploring Data With Sql   Part 1.mp4
# Data Analyst Projects   Visualizing Data With Tableau   Part 2.mp4
# Data Analytics Using Python And Sql 2022   Data Analytics Full Course For Beginners   Simplilearn.mp4
# Dataeditr Tutorial - Interactively Edit Datasets Using R.mp4
# Dax In Excel Explained  Excel Dax Formulas And Dax Functions  Excel Tutorial  Simplilearn.mp4
# Day In The Life Of A Software Engineer - First Person View - Working At The Kahoot Office.mp4
# Decision Trees In R   Rpart Library.mp4
# Deep Maths - Machine Learning And Mathematics.mp4
# Deploy You Machine Learning Model With Python.mp4
# Depressed Parents Take Revenge On Psychopath Who K1Lled Their Son.mp4
# Did Russia Want To Take Kiev That Was Never The Plan Says Russia.mp4
# Do Sanctions Work .mp4
# Documentary
# Don’T Waste Your Money!! Ipad Pro Vs Galaxy Tab S8 Ultra.mp4
# Easily Unlock Protected Excel Sheets Without Password.mp4
# English
# Excel 2019 Pivot Tables Tutorial.mp4
# Excel Crash Course - Data Cleaning In Excel - Microsoft Excel Tutorial.mp4
# Excel Interview Questions For Data Analyst.mp4
# Excel Tips & Tricks  Designing Better Spreadsheets - 1-Hour Excel Tutorial.mp4
# Excel Tutorials - Top Ten Excel Functions You Have To Know - Excel 2019 (If, Vlookup, Sum, Pmt).mp4
# Fedora Is The New Ubuntu - Fedora Long Term Review.mp4
# Firefox Dying Is Terrible For The Web.mp4
# First Nato Air Losses - Ukraine War.mp4
# For 7 Years In Prison He Studied Quantum Physics And Learned How To Always Win In Any Game.mp4
# Full Project In Excel  Excel Tutorials For Beginners.mp4
# George Mount   R For Excel Users - First Steps   Rstudio Meetup.mp4
# Git Tutorial For Beginners 2022  Git & Github Complete Tutorial  Learn Git In 2 Hrs  Simplilearn.mp4
# Gross Things Actors Had To Actually Do For A Role.mp4
# He Became Top Rated Freelancer In First 4 Months On Upwork  Data Analyst Freelancer.mp4
# How Many Nuclear Missiles Can The United States Intercept.mp4
# How To Become A Freelance Data Scientist Or Data Analyst.mp4
# How To Create Resume In Tableau   Tableau Resume Dashboard Example.mp4
# How To Create Text Mining Project In R  Customize Stopwords In R Text Analytics In R.mp4
# How To Create Your Own Hexsticker Using R (Hexsticker Package).mp4
# How To Download Files From Websites Using R.mp4
# How To Importexport Data To Csv Files Using Powershell.mp4
# How To Over Engineer A Website  What Is A Tech Stack.mp4
# How To Think Like A Programmer.mp4
# Html & Css Full Course - Beginner To Pro (2022).mp4
# I Tried Coding On A Chromebook For 7 Days.mp4
# Interior Design
# Intermediate Python Programming Course.mp4
# Introduction To Jupyterlab.mp4
# Introduction To Selenium Using R (Rselenium).mp4
# Ipl Data Analysis Using Python 2022  Data Analysis Project  Tata Ipl 2022 Python  Simplilearn.mp4
# Iq15  6 Sql Query Interview Questions.mp4
# Irene Steves  The Dynamic Duo Sql & R  Rstudio.mp4
# James Blair  Getting Started With {Plumbertableau}  Rstudio.mp4
# Journalist Can'T Refuse The Offer He Gets From A Mysterious Woman.mp4
# Json Crash Course.mp4
# Json In Python    Python Tutorial    Learn Python Programming.mp4
# Jupyterlab Is Now Available As A Desktop App - Here’S How To Use It   Better Data Science.mp4
# Learn Html5 And Css3 From Scratch - Full Course.mp4
# Learn Json In 10 Minutes.mp4
# Learn Sql In 1 Hour - Sql Basics For Beginners.mp4
# Learn Sql In 60 Minutes.mp4
# Lenovo Thinkpad X13S Hands-On At Mwc 2022.mp4
# Lockheed Sr-71 Blackbird  New York To London In 1H 54 Mins  The Untouchable Reconnaissance Plane.mp4
# Logical Functions In Excel Tutorial (If, Ifs, And, Or, Countif, Sumif) Excel Formulas And Functions.mp4
# Mac Studio M1 Base Model Review  Unboxing, First Impressions & Performance.mp4
# Mac Studio 👍 Studio Display 👎.mp4
# Make Money With Coding   What You'Re Not Being Told!.mp4
# Match() Function In R (4 Example Codes)  Pmatch() & Charmatch() Functions  String & Numeric Data.mp4
# Modern Loft Apartment Makeover - Final Reveal, Furniture, Desk Setups!.mp4
# Modern Office Loft & Desk Setup Tour (2021).mp4
# Most Powerful Military In 2022 Ranked.mp4
# Movies
# Music
# My M1 Pro Macbook Pro 16 Setup For Programming & Productivity.mp4
# My Most Productive Desk Setup Ever - 2022 Upgrades.mp4
# Mysql Syntax In 20 Minutes  Understanding The Main Components Of Sql.mp4
# Nikita Khrushchev The Red Tsar - Full Documentary.mp4
# Object Oriented Programming With Python - Full Course For Beginners.mp4
# Oikos Workshop  Data Visualization In R Using Ggplot2.mp4
# Old Lady Reveals The Sin She Witnessed In The 1890S In Rural Maine.mp4
# Oop Class Inheritance And Private Class Members - Python For Beginners!.mp4
# Open Source Software Has A Funding Problem .mp4
# Pivot Table Tutorial - Learn Pivottables In 1 Hour - Excel Crash Course.mp4
# Pivot Tables Excel Detailed Beginners Pivot Table Tutorial.mp4
# Portfolio Website Tutorial – Frontend Development With Html, Css, Javascript.mp4
# Programming Games With Shiny  Dragon Realm  Rstudio.mp4
# Pros And Cons Of Working Remote   Alex The Analyst Show   Episode 21.mp4
# Python Pandas Tutorial 5  How To Delete Rows And Columns From A Data Frame.mp4
# Python Pandas Tutorial 9  How To Import Excel Data In Python  Getting Excel Data In Python.mp4
# Python Website Full Tutorial - Flask, Authentication, Databases & More.mp4
# R Shiny For Data Science Tutorial – Build Interactive Data-Driven Web Apps.mp4
# R Shiny Tutorial For Beginners [Complete Tutorial] - Part 1.mp4
# R Shiny Tutorial For Beginners [Complete Tutorial] - Part 2.mp4
# R-Ladies Freiburg (English) - Our First Data Dashboard Interactive Plots With Shiny!.mp4
# R-Ladies New York (English) - Panel Discussion  Working With & Learning From Covid-19 Data.mp4
# Real Reason Why The Soviet Union Collapsed.mp4
# Real-World Data Analysis  Exploring Lego Dataset With Sql  Data Analyst Projects.mp4
# Recent Losses Of The Russian Army Announced.mp4
# Rselenium Package In R (Example)  Automate Web Browsers  Introduction & Tutorial For Beginners.mp4
# Rselenium Package In R (Example)   Automate Web Browsers   Introduction & Tutorial For Beginners.mp4
# Ruby On Rails Crash Course.mp4
# Ruby Programming Language - Full Course.mp4
# Samsung Smart Monitor M8 Unboxing And Hands On!.mp4
# She Allows Him To Do Anything With Her Body.mp4
# She Ends Up In A Japanese Concentration Camp For European Women Where They Aren’T Considered Human.mp4
# Software Engineering Vs Data Science In Practice.mp4
# Studio Display - Unboxing & Review.mp4
# T-Test And Interpreting P Values Using R Programming.mp4
# Tableau
# Tableau Destination Maps.mp4
# The 50 Most Popular Linux & Terminal Commands - Full Course For Beginners.mp4
# The Apple Studio Display Is A Bad Deal.mp4
# The Boeing Ch-47 Chinook.mp4
# The F-35 Lightning  Jack Of All Trades, Or Master Of None .mp4
# The First Minutes The Dinosaurs Went Extinct.mp4
# The Insane Engineering Of The Concorde.mp4
# The Nazi Bomber Made To Destroy New York - The Horten H Xviii 18 Flying Wing America Bomber.mp4
# The World’S Fastest Bomber The Xb-70 Valkyrie.mp4
# This Company Owns The World (And It'S Our Fault) - Blackrock.mp4
# This Excel Chart Will Grab Your Attention (Infographic Template Included).mp4
# Travel & Adventure
# Turn Your Excel Data Into An Interactive Dashboard Using Python  Pyecharts Tutorial.mp4
# Turning Old Floorboards Into The Ultimate Sound-System!.mp4
# Tutorial On Text Analysis Twitter Data In R.mp4
# Types Of Men Wakinyimwa.mp4
# Ukraine'S Lost Strategic Bomber Fleet.mp4
# Ultimate Freelancing Guide For Web Developers (Make Money Through Freelance Programming!).mp4
# Use This Algorithm To Find Keywords In Text - A Short Python Project.mp4
# Using The Old Youtube App In 2022!.mp4
# Visual Studio Code Extensions To Improve Your Productivity.mp4
# We Bought 6 Dead Gpus  Can We Fix Them.mp4
# Web Scraping + Data Cleaning Project Using R - Tom Brady Statistics.mp4
# What Data Science Courses Don'T Teach You 🤫.mp4
# What Is An Api.mp4
# What Was Libya Like 20 Years Ago.mp4
# Why Did The World’S Best Chess Player Go Insane.mp4
# Why Did The World’S Best Chess Player Go Insane .mp4
# Why Do Russians Submarines Have Windows #Shorts.mp4
# Why Do Women Go To The Club.mp4
# Why I Chickened Out Of Computer Science.mp4
# Why Isn'T China Supporting Putin In Ukraine - Visualpolitik En.mp4
# Why Julia A High Level Description Of The Features And Benefits Of Programming In Julia .mp4
# Working With Csv'S In Windows Powershell.mp4
# Yaml  In One Video.mp4
# You Can Do Really Cool Things With Functions In Python.mp4
# You Need To Learn Bash Scripting Right Now!!  Ep 1.mp4
# Your Phone Could Be Your Laptop  Here'S Why It Won'T .mp4
